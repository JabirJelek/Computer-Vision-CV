# %%
# Create a new directory for your project
#mkdir yolo_object_detection
#cd yolo_object_detection

# Create a virtual environment (optional but recommended)
#python -m venv yolo_env
#source yolo_env/bin/activate  # On Windows: yolo_env\Scripts\activate

# Install required packages
#!pip install torch torchvision torchaudio
# !pip install ultralytics  # This includes YOLOv8
# !pip install opencv-python
#!pip install matplotlib
#!pip install numpy
#!pip install opencv-python>=4.6.0
#!pip install pandas
#!pip install Pillow
#!pip install pyYAML
#!pip install requests
#!pip install tqdm
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 18.9 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
# Define paths
dir_path = "/content/drive/MyDrive/ObjectDetection-Tasks"
filepath = os.path.join(dir_path, "Task-for-model-2")
dataset_path = os.path.join(filepath, 'retrainDataset/labelData0')  # New structured dataset location

save_dir = os.path.join(dataset_path, 'batch2')
labels_source = os.path.join(dataset_path, "label_retrain_batch_1.json") # Change this directory target into the converted directory
images_source = os.path.join(filepath,  "retrainDataset/imageData") # add this if in another directory , "captured_frames"

# %%
from ultralytics.data.converter import convert_coco
convert_coco(labels_dir=dataset_path, save_dir=save_dir, use_segments=True)
# Out:
# Annotations /content/drive/MyDrive/ObjectDetection-Tasks/Task-for-model-2/retrainDataset/labelData0/label_retrain_batch_2.json: 100% ━━━━━━━━━━━━ 55/55 148.5it/s 0.4s
# COCO data converted successfully.
# Results saved to /content/drive/MyDrive/ObjectDetection-Tasks/Task-for-model-2/retrainDataset/labelData0/batch2
