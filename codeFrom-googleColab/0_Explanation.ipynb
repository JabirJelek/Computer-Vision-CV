# %% [markdown]
# # This colab is used to explain the numbering in Colab.

# %% [markdown]
# ---
#
# The reason why there are numbering, (e.g. 0_ ; 1_ ; 2_) is to understand the structure whereas the smaller the number, the earlier version of the code it was. While n+1 means the number of project / code that has run multiple time in the different project.
#
# ---
#
# As much as possible, avoid changing the 0_, because it was a stable code that already run previously, and just copy the o_ or copy the newest code to make sure that i didn't forget about my code, and recreating everything from 0 is time consuming.
#
# ---
#
# JUST RE-USE MY ALREADY IMPLEMENTED CODE, AND CHANGE THE DIRECTORY LOCATION ACCORDINGLY!!!

# %% [markdown]
# ## Further explain

# %% [markdown]
# Below are explanation about why the first numbering.
#
# 1.   0 = This is the base knowledge structure. As much as possible, dont change notebook with this number, because it will always updated in further project
# 2.   1 = This project is for APD detection from SCMA
# 3.   2 = This project is for IPE item detection in the box
# 4.   3 = This project is for speech to text model creation.
# 5.   4 =
